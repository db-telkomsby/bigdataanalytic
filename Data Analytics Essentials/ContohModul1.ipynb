# %%
print("Kalau aku Chat kamu, ada yang marah gk ?")

# %%
df = 'is data frame'
df
print(df)
# Out:
# is data frame

# %% [markdown]
# # **Contoh Data Exploration**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

#import data dari Gdrive
df_link = pd.read_csv('/content/drive/MyDrive/Data/data_praktikum.csv',sep=";")
df = df_link
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import data langsung ke G colab
df_link2 = pd.read_csv('Book1Revisi.csv',sep=",")
df2 = df_link2
df2
# Out:
#       Tanggal    Produk    Kategori    Harga  Jumlah Terjual    Toko      Kota
# 0    9/1/2023  Produk A  Elektronik  $500.00            10.0  Toko 1   Jakarta
# 1    9/2/2023  Produk B     Pakaian      NaN            20.0  Toko 2  Surabaya
# 2    9/3/2023       NaN  Alat Masak   $75.00             NaN  Toko 3   Bandung
# 3         NaN  Produk D         NaN   $20.00            30.0     NaN       NaN
# 4    9/5/2023  Produk E  Elektronik      NaN             5.0  Toko 4     Medan
# 5    9/6/2023  Produk F         NaN   $40.00            25.0  Toko 2  Surabaya
# 6    9/7/2023  Produk A  Elektronik      NaN             NaN  Toko 5       NaN
# 7    9/8/2023  Produk B     Pakaian   $35.00             NaN     NaN   Bandung
# 8    9/9/2023       NaN  Alat Masak   $75.00            12.0  Toko 1       NaN
# 9   9/10/2023  Produk D         NaN      NaN             NaN  Toko 4     Medan
# 10  9/11/2023  Produk E  Elektronik  $900.00             NaN  Toko 2  Surabaya
# ...

# %% [markdown]
# Cara membaca data

# %%
#melihat data awal
df2.head(5)
# Out:
#     Tanggal    Produk    Kategori    Harga  Jumlah Terjual    Toko      Kota
# 0  9/1/2023  Produk A  Elektronik  $500.00            10.0  Toko 1   Jakarta
# 1  9/2/2023  Produk B     Pakaian      NaN            20.0  Toko 2  Surabaya
# 2  9/3/2023       NaN  Alat Masak   $75.00             NaN  Toko 3   Bandung
# 3       NaN  Produk D         NaN   $20.00            30.0     NaN       NaN
# 4  9/5/2023  Produk E  Elektronik      NaN             5.0  Toko 4     Medan

# %%
#melihat data akhir
df2.tail(5)
# Out:
#       Tanggal    Produk Kategori   Harga  Jumlah Terjual    Toko      Kota
# 25  9/26/2023  Produk B  Pakaian     NaN            21.0  Toko 2  Surabaya
# 26  9/27/2023  Produk C      NaN  $75.00            16.0     NaN  Semarang
# 27  9/28/2023  Produk D   Mainan     NaN            32.0  Toko 3   Bandung
# 28  9/29/2023       NaN      NaN  $20.00             2.0  Toko 1       NaN
# 29  9/30/2023  Produk F  Pakaian  $40.00            26.0  Toko 4     Medan

# %%
#melihat jumlah kolom dan baris
df2.shape
# Out:
# (30, 7)

# %%
#melihat informasi data
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Tanggal         26 non-null     object
#  1   Produk          24 non-null     object
#  2   Kategori        23 non-null     object
#  3   Harga           21 non-null     object
#  4   Jumlah Terjual  22 non-null     float64
#  5   Toko            23 non-null     object
#  6   Kota            21 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.8+ KB

# %% [markdown]
# Pemusatan data (Central Tendency Measurements)

# %%
#melihat mean data
df2.columns
df_num = df2[['Harga','Jumlah Terjual']]
df_num.mean()
# Out:
# <ipython-input-9-b1678981370a>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_num.mean()
# Jumlah Terjual    16.909091
# dtype: float64

# %%
df_num.median()
# Out:
# <ipython-input-10-d4ba9c5d67f7>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_num.median()
# Jumlah Terjual    17.5
# dtype: float64

# %%
df_num.mode()
# Out:
#      Harga  Jumlah Terjual
# 0   $40.00             2.0
# 1      NaN             3.0
# 2      NaN             5.0
# 3      NaN             6.0
# 4      NaN             7.0
# 5      NaN            10.0
# 6      NaN            11.0
# 7      NaN            12.0
# 8      NaN            13.0
# 9      NaN            14.0
# 10     NaN            16.0
# 11     NaN            19.0
# 12     NaN            20.0
# 13     NaN            21.0
# 14     NaN            22.0
# 15     NaN            23.0
# 16     NaN            24.0
# 17     NaN            25.0
# 18     NaN            26.0
# 19     NaN            30.0
# 20     NaN            31.0
# 21     NaN            32.0

# %% [markdown]
# Cara Korelasi data

# %%
# Melihat korelasi data menggunakan metode kendal
correlation_matrix = df2.corr(method='kendall')

# Print Correlation Matrix
correlation_matrix
# Out:
# <ipython-input-12-bb4f82e98fe2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df2.corr(method='kendall')
#                 Jumlah Terjual
# Jumlah Terjual             1.0

# %% [markdown]
# Cara visualisasi data

# %%
#import library Matplotlib dan Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#visualisasi data menggunakan scatterplot
sns.scatterplot(x='Harga', y='Jumlah Terjual', data= df2)
# Out:
# <Axes: xlabel='Harga', ylabel='Jumlah Terjual'>

# %% [markdown]
# # **Contoh Data Preparation**

# %%
# Mengganti nilai yang hilang dengan nilai default (misalnya, 0) atau nilai yang sesuai
# Di sini, kita akan mengganti nilai yang hilang di kolom 'Harga' dan 'Jumlah Terjual' dengan 0
df2['Harga'].fillna(0, inplace=True)
df2['Jumlah Terjual'].fillna(0, inplace=True)
df2
# Out:
#      Tanggal            Produk        Kategori        Harga     \
# 0    2023-09-01         Produk A      Elektronik      500.00
# 1    2023-09-02         Produk B      Pakaian
# 2    2023-09-03                       Alat Masak      75.00
# 3                       Produk D                      20.00
# 4    2023-09-05         Produk E      Elektronik
# 5    2023-09-06         Produk F                      40.00
# 6    2023-09-07         Produk A      Elektronik
# 7    2023-09-08         Produk B      Pakaian         35.00
# 8    2023-09-09                       Alat Masak      75.00
# 9    2023-09-10         Produk D
# 10   2023-09-11         Produk E      Elektronik      900.00
# 11   2023-09-12                                       40.00
# 12   2023-09-13         Produk A      Elektronik
# 13   2023-09-14         Produk B      Pakaian         35.00
# 14                      Produk C
# 15   2023-09-16         Produk D      Mainan          20.00
# ...

# %%
# Menghapus baris yang memiliki nilai yang hilang di beberapa kolom atau baris yang benar-benar kosong
#df2.dropna(subset=['Kategori'], inplace=True)  # Contoh: Menghapus baris dengan nilai kosong di kolom 'Kategori'

# %%
# Merapikan dataset dengan menghapus baris duplikat (jika ada)
df2.drop_duplicates(inplace=True)

# %%
# Menyimpan dataset yang telah diolah ke dalam file CSV
# Gantilah 'nama_file_cleaned.csv' dengan nama file yang sesuai
df2.to_csv('nama_file_cleaned.csv', index=False)
