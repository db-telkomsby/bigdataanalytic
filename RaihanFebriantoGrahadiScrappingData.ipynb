# %% [markdown]
# <a href="https://colab.research.google.com/github/db-telkomsby/bigdataanalytic/blob/main/RaihanFebriantoGrahadiScrappingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
# Scrape All available reviews
#(DONT RUN THIS CELL!!! RUN ONLY IF YOU WANT TO SCRAPE ALL AVAILABLE REVIEWS)
#JANGAN DI RUN KODE INI, KECUALI ANDA INGIN SCRAPE SEMUA REVIEWS SEKALIGUS

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.instagram.android',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
)

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.instagram.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=200, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId       userName  \
# 0  6bc61065-dc06-42cd-9953-59cb78f53af7  ai nursadiyah
# 1  d504d1fd-aec2-4a9d-991d-bf7c9247cbd4     Gatot Koco
# 2  7b06cd9c-1001-49ad-b8a4-321607638469     Nisa Jelek
# 3  c2f0207a-057f-4d2c-a113-f90d0da11c5e   Sri Agustina
# 4  5ae1d425-bd4b-450d-ac7e-94c64e7ba3ee    Shita Aulya
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Freepalestine dont stop us to suport palestine...      1              1
# 1                                                 Ok      5              1
# 2                      Perbaikan bug dan setabilitas      5              0
# 3  Instagram support genocide, Stop genocide, fre...      1             39
# 4                           Not support democracy...      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0        293.0.2.28.93 2023-12-04 01:45:52         None      None
# 1       309.1.0.41.113 2023-12-03 15:00:09         None      None
# 2                 None 2023-12-03 04:55:18         None      None
# 3       309.1.0.41.113 2023-12-01 20:12:11         None      None
# 4       309.1.0.41.113 2023-12-01 03:47:58         None      None
#
#        appVersion
# 0   293.0.2.28.93
# 1  309.1.0.41.113
# 2            None
# 3  309.1.0.41.113
# 4  309.1.0.41.113

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 200

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#         userName  score                  at  \
# 0  ai nursadiyah      1 2023-12-04 01:45:52
# 1     Gatot Koco      5 2023-12-03 15:00:09
# 2     Nisa Jelek      5 2023-12-03 04:55:18
# 3   Sri Agustina      1 2023-12-01 20:12:11
# 4    Shita Aulya      1 2023-12-01 03:47:58
#
#                                              content
# 0  Freepalestine dont stop us to suport palestine...
# 1                                                 Ok
# 2                      Perbaikan bug dan setabilitas
# 3  Instagram support genocide, Stop genocide, fre...
# 4                           Not support democracy...

# %%
#Run This Code to Sort the Data By Date

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#         userName  score                  at  \
# 0  ai nursadiyah      1 2023-12-04 01:45:52
# 1     Gatot Koco      5 2023-12-03 15:00:09
# 2     Nisa Jelek      5 2023-12-03 04:55:18
# 3   Sri Agustina      1 2023-12-01 20:12:11
# 4    Shita Aulya      1 2023-12-01 03:47:58
#
#                                              content
# 0  Freepalestine dont stop us to suport palestine...
# 1                                                 Ok
# 2                      Perbaikan bug dan setabilitas
# 3  Instagram support genocide, Stop genocide, fre...
# 4                           Not support democracy...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.head()
# Out:
#         userName  score                  at  \
# 0  ai nursadiyah      1 2023-12-04 01:45:52
# 1     Gatot Koco      5 2023-12-03 15:00:09
# 2     Nisa Jelek      5 2023-12-03 04:55:18
# 3   Sri Agustina      1 2023-12-01 20:12:11
# 4    Shita Aulya      1 2023-12-01 03:47:58
#
#                                              content
# 0  Freepalestine dont stop us to suport palestine...
# 1                                                 Ok
# 2                      Perbaikan bug dan setabilitas
# 3  Instagram support genocide, Stop genocide, fre...
# 4                           Not support democracy...

# %%
my_df.to_csv("DIGBIS01-03.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
